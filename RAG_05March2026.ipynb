# %% [markdown]
# <a href="https://colab.research.google.com/github/tselane2110/basic-RAG/blob/main/RAG_05March2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Maarij-Moin/basic-rag-from-scratch
# Out:
# Cloning into 'basic-rag-from-scratch'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 24 (delta 5), reused 23 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 14.69 KiB | 417.00 KiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# !pip install ollama

# %%
# !apt-get update
# !apt-get install -y zstd
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.2 kB]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [357 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,810 kB]
# Get:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
import subprocess
subprocess.Popen(["ollama", "serve"])
# Out:
# <Popen: returncode: None args: ['ollama', 'serve']>

# %%
# !ollama pull 'hf.co/CompendiumLabs/bge-base-en-v1.5-gguf' # embedding model
# !ollama pull 'hf.co/bartowski/Llama-3.2-1B-Instruct-GGUF' # instruction model

# %%
# !ollama list
# Out:
# NAME                                                 ID              SIZE      MODIFIED
# hf.co/CompendiumLabs/bge-base-en-v1.5-gguf:latest    98c4eb4a3287    68 MB     About a minute ago
# hf.co/bartowski/Llama-3.2-1B-Instruct-GGUF:latest    042cf58aa32f    807 MB    About a minute ago

# %%
# !ollama run hf.co/bartowski/Llama-3.2-1B-Instruct-GGUF
